# %% [markdown]
# <a href="https://colab.research.google.com/github/smartyAe/My-all-data-science-learning-exercises-and-projects/blob/main/MontyHall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
from random import randint, shuffle, choice
import matplotlib.pyplot as plt
import numpy as np

# %%
def playgame(changeChoice):
  portes=[1,2,3]
  bonchoix=randint(0,2)
  choix1=randint(0,2)
  
  portes.remove(portes[choix1])
  if choix1==bonchoix:
    portes.remove(portes[randint(0,1)])
  else:
    portes=[bonchoix]
  choix2=0
  if not changeChoice:
    choix2=choix1
  else:
    choix2=portes[0]
  return choix2==bonchoix

# %%
def play(change,nb_parties):
  return [1 if playgame(change) else 0 for i in range(nb_parties)]

# %%
plt.figure(figsize=(16, 5))

plt.subplot(121)
plt.plot(play(True,20))
plt.subplot(122)
plt.plot(play(False,20))
plt.show()

# %%
plt.bar([1,2],[sum(play(False,1000)),sum(play(True,1000))], tick_label=["Garder","Changer"])
# Out:
# <BarContainer object of 2 artists>

# %%
gains_changer = []
gains_garder = []
samples =  [1000, 10000, 20000, 50000, 80000, 100000]
for tours in samples:
    gains_changer.append(play(True, tours))
    gains_garder.append(play(False, tours))

# %%
plt.scatter(samples,[sum(x) for x in gains_changer])
plt.scatter(samples,[ sum(x) for x in gains_garder])

# %%
plt.scatter(samples,[sum(x)/i for x,i in zip(gains_changer,samples)])
plt.scatter(samples,[sum(x)/i for x,i in zip(gains_garder,samples)])

# %%
[sum(x)/i for x,i in zip(gains_changer,samples)]
# Out:
# [0.769, 0.7814, 0.7737, 0.77998, 0.778925, 0.77571]

# %%
[sum(x)/i for x,i in zip(gains_garder,samples)]
# Out:
# [0.332, 0.3386, 0.32785, 0.3379, 0.3337, 0.33446]
